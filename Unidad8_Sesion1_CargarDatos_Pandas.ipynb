# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Unidad8_Sesion1_CargarDatos_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1nptVTliqyIIOzwF08JXJkWEvlYUC4_g5'  width="1500" height="300">

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Pandas básico</h1>
# </div>

# %% [markdown]
# # 1. Introducción a Pandas

# %% [markdown]
# ## ¿Qué es pandas?
# Es una librería de análisis de datos que se compone de una serie de estructuras de datos con funcionalidades para limpiar, analizar y preprocesar los datos para tareas siguientes al análisis.
#
# ![wget](https://drive.google.com/uc?export=view&id=1mbFgZLmt0qD80FleVEj4cpxh5oO3ocvQ)

# %% [markdown]
# ## Importando pandas
# Pandas se puede importar de la siguiente manera. Se utiliza el nombre pd por facilidad de manejo.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
# Una serie es un arreglo unidimensional con un índice correspondiente a cada posición del arreglo. Por ejemplo, el listado de jugadores de un equipo, donde el arreglo tiene los apellidos de los jugadores y el índice el número del jugador.

# %%
seleccionColombia = pd.Series(
    ['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'],
    index=[1, 2, 9, 11, 10])

# %% [markdown]
# Como se puede observar con los jugadores Cuadrado y Rodriguez, los índices no tienen que estar necesariamente ordenados. La serie se puede imprimir escribiendo su identificador.

# %%
seleccionColombia
# Out:
# 1        Ospina
# 2        Zapata
# 9        Falcao
# 11     Cuadrado
# 10    Rodriguez
# dtype: object

# %% [markdown]
# Una serie se puede generar sin conocer los índices y Pandas los generará automáticamente con valores desde cero hasta el tamaño de la lista menos uno. En el caso de la misma serie:

# %%
seleccionColombia = pd.Series(
    ['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'])
seleccionColombia
# Out:
# 0       Ospina
# 1       Zapata
# 2       Falcao
# 3     Cuadrado
# 4    Rodriguez
# dtype: object

# %% [markdown]
# ### Series desde Diccionarios
#
# Las series tambien pueden ser definidas desde diccionarios:

# %%
dict_selcol = {1:'Ospina', 2: 'Zapata', 9: 'Falcao', 11: 'Cuadrado', 10: 'Rodriguez'}
print(dict_selcol)
# Out:
# {1: 'Ospina', 2: 'Zapata', 9: 'Falcao', 11: 'Cuadrado', 10: 'Rodriguez'}

# %%
ser_selcol = pd.Series(dict_selcol)
ser_selcol.head()
# Out:
# 1        Ospina
# 2        Zapata
# 9        Falcao
# 11     Cuadrado
# 10    Rodriguez
# dtype: object

# %% [markdown]
# ### Usando los índices
#
# Los índices son la clave para entender cómo usar las Series. Pandas usa los nombres de los índices o sus números para permitir la búsqueda rápida de información (funcionan como una tabla hash o un diccionario).
#
# Para el ejemplo, vamos a crear 2 Series: ser1 y ser2

# %%
ser1 = pd.Series([10,20,30,40,0],index = ['Peru','Colombia', 'Germany','Spain', 'Japan'])

# %%
ser1
# Out:
# Peru        10
# Colombia    20
# Germany     30
# Spain       40
# Japan        0
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4,5],index = ['Germany','Colombia','Colombia','Italy', 'Japan'])

# %%
ser2
# Out:
# Germany     1
# Colombia    2
# Colombia    5
# Italy       4
# Japan       5
# dtype: int64

# %%
ser2['Colombia']
# Out:
# Colombia    2
# Colombia    5
# dtype: int64

# %%
ser1[3]
# Out:
# /tmp/ipython-input-1464167641.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser1[3]
# np.int64(40)

# %% [markdown]
# También, se pueden hacer operaciones entre Series:

# %%
ser1
# Out:
# Peru        10
# Colombia    20
# Germany     30
# Spain       40
# Japan        0
# dtype: int64

# %%
ser2
# Out:
# Germany     1
# Colombia    2
# Colombia    5
# Italy       4
# Japan       5
# dtype: int64

# %%
ser1 + ser2
# Out:
# Colombia    22.0
# Colombia    25.0
# Germany     31.0
# Italy        NaN
# Japan        5.0
# Peru         NaN
# Spain        NaN
# dtype: float64

# %%
ser1 / ser2
# Out:
# Colombia    10.0
# Colombia     4.0
# Germany     30.0
# Italy        NaN
# Japan        0.0
# Peru         NaN
# Spain        NaN
# dtype: float64

# %% [markdown]
# ## DataFrame
# Un DataFrame es una estructura de datos que almacena la información como una tabla ordenada por filas y columnas. Cada fila representa un objeto y cada columna la información correspondiente a una característica de los objetos.
#
# Un DataFrame también posee índices por cada fila, que pueden ser dados o generados automáticamente. Cada columna del DataFrame es una serie, donde el valor del índice corresponde con los valores de índice que tiene el DataFrame.
#
# Por medio de un diccionario vamos a crear un dataframe, donde las llaves son los nombres de las columnas y los valores son la lista de valores que tienen las características.
#
# Por ejemplo, para hacer un DataFrame con el equipo de fútbol anterior, pero agregando estatura y peso, podemos hacerlo de la siguiente manera:

# %%
dict_caracteristicas = {'apellido':['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'],
                       'altura':[183.0,187.0,177.0,179.0,180.0],
                       'peso':[80.0,82.0,72.0,72.0,75.0]}

seleccionColombia = pd.DataFrame(dict_caracteristicas,index=[1, 2, 9, 11, 10])

# %% [markdown]
# Al imprimir el DataFrame, podemos observar que su estructura es similar a la de un documento en Excel, donde el índice (que no tiene nombre de columna) es el número del jugador.

# %%
seleccionColombia
# Out:
#      apellido  altura  peso
# 1      Ospina   183.0  80.0
# 2      Zapata   187.0  82.0
# 9      Falcao   177.0  72.0
# 11   Cuadrado   179.0  72.0
# 10  Rodriguez   180.0  75.0

# %% [markdown]
# ### Acceso a los registros del DataFrame por el índice

# %% [markdown]
# En pandas podemos acceder a la fila por el índice de ésta. En el ejemplo anterior este índice era el número de la camiseta del jugador. Pero podría ser una fecha, una letra, etc.
#
# Si conocemos el índice simplemente lo usamos para ir directamente a la fila deseada.

# %%
seleccionColombia.loc[9]
# Out:
# apellido    Falcao
# altura       177.0
# peso          72.0
# Name: 9, dtype: object

# %% [markdown]
# Para agregar un nuevo jugador, se puede utilizar el índice, que en este caso es el número en el equipo y un arreglo representando todas sus características (apellido, altura y peso).
#
# NOTA: Las características tienen que estar en el mismo orden.

# %%
num_jugador = 3
caract_jugador = ['Murillo',184.0,80.0]
seleccionColombia.loc[num_jugador] = caract_jugador

# %% [markdown]
# Imprimiendo el DataFrame podemos ver el nuevo jugador.

# %%
seleccionColombia
# Out:
#      apellido  altura  peso
# 1      Ospina   183.0  80.0
# 2      Zapata   187.0  82.0
# 9      Falcao   177.0  72.0
# 11   Cuadrado   179.0  72.0
# 10  Rodriguez   180.0  75.0
# 3     Murillo   184.0  80.0

# %% [markdown]
# ###Creando una columna nueva

# %%
seleccionColombia['IMC'] = seleccionColombia['peso'] / (seleccionColombia['altura'] ** 2) * 100

# %%
seleccionColombia
# Out:
#      apellido  altura  peso       IMC
# 1      Ospina   183.0  80.0  0.238884
# 2      Zapata   187.0  82.0  0.234493
# 9      Falcao   177.0  72.0  0.229819
# 11   Cuadrado   179.0  72.0  0.224712
# 10  Rodriguez   180.0  75.0  0.231481
# 3     Murillo   184.0  80.0  0.236295

# %%
seleccionColombia['Numero_partidos_jugados'] = [13, 7, 45, 20, 25, 10]

# %%
seleccionColombia
# Out:
#      apellido  altura  peso       IMC  Numero_partidos_jugados
# 1      Ospina   183.0  80.0  0.238884                       13
# 2      Zapata   187.0  82.0  0.234493                        7
# 9      Falcao   177.0  72.0  0.229819                       45
# 11   Cuadrado   179.0  72.0  0.224712                       20
# 10  Rodriguez   180.0  75.0  0.231481                       25
# 3     Murillo   184.0  80.0  0.236295                       10

# %% [markdown]
# ### Borrar Columna o Fila

# %%
seleccionColombia
# Out:
#      apellido  altura  peso       IMC  Numero_partidos_jugados
# 1      Ospina   183.0  80.0  0.238884                       13
# 2      Zapata   187.0  82.0  0.234493                        7
# 9      Falcao   177.0  72.0  0.229819                       45
# 11   Cuadrado   179.0  72.0  0.224712                       20
# 10  Rodriguez   180.0  75.0  0.231481                       25
# 3     Murillo   184.0  80.0  0.236295                       10

# %%
seleccionColombia.drop('peso',axis=1) # Para que sea permanente inplace=True
# Out:
#      apellido  altura       IMC  Numero_partidos_jugados
# 1      Ospina   183.0  0.238884                       13
# 2      Zapata   187.0  0.234493                        7
# 9      Falcao   177.0  0.229819                       45
# 11   Cuadrado   179.0  0.224712                       20
# 10  Rodriguez   180.0  0.231481                       25
# 3     Murillo   184.0  0.236295                       10

# %% [markdown]
# Si queremos eliminar una columna permanentemente también se puede usar:

# %%
del seleccionColombia['peso']

# %%
seleccionColombia
# Out:
#      apellido  altura       IMC  Numero_partidos_jugados
# 1      Ospina   183.0  0.238884                       13
# 2      Zapata   187.0  0.234493                        7
# 9      Falcao   177.0  0.229819                       45
# 11   Cuadrado   179.0  0.224712                       20
# 10  Rodriguez   180.0  0.231481                       25
# 3     Murillo   184.0  0.236295                       10

# %% [markdown]
# Si queremos saber cuales son las columnas actuales del data frame, usamos la propiedad 'columns' del objeto.

# %%
seleccionColombia.columns
# Out:
# Index(['apellido', 'altura', 'IMC', 'Numero_partidos_jugados'], dtype='object')

# %% [markdown]
# Si queremos conocer el indice del dataframe, con lo propiedad 'index' la conocemos.

# %%
seleccionColombia.index
# Out:
# Index([1, 2, 9, 11, 10, 3], dtype='int64')

# %% [markdown]
# Para ordenar el dataframe se usa la función sort.

# %%
seleccionColombia.sort_values(by='altura') #inplace=False por defecto
# Out:
#      apellido  altura       IMC  Numero_partidos_jugados
# 9      Falcao   177.0  0.229819                       45
# 11   Cuadrado   179.0  0.224712                       20
# 10  Rodriguez   180.0  0.231481                       25
# 1      Ospina   183.0  0.238884                       13
# 3     Murillo   184.0  0.236295                       10
# 2      Zapata   187.0  0.234493                        7

# %% [markdown]
# ## Datos faltantes: rellenar valores NaN con algo más
#
# En algunas ocaciones vamos a tener valor inválidos en nuestros dataframes. Estos valores son un problema al momento de hacer cálculos numéricos o tomar estadísticas.
#
# Para esto es necesario dejar fuera del dataframe estos campos.
#
# En las siguientes líneas usted verá como se eliminan estos valores.

# %%
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %% [markdown]
# **Hallar valores NULL o verificarlos**

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False   True  False
# 1  False  False  False
# 2  False  False  False
# 3   True  False  False

# %%
df.fillna('VALOR') # inplace=False por defecto
# Out:
#     col1   col2 col3
# 0    1.0  VALOR  abc
# 1    2.0  555.0  def
# 2    3.0  666.0  ghi
# 3  VALOR  444.0  xyz

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
# En este caso, se usará la media de los valores de la Columna 2 para llenar sus valores faltantes:
df['col2'].fillna(value=df['col2'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3600979702.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['col2'].fillna(value=df['col2'].mean(), inplace=True)

# %%
df
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
# Eliminar filas con valores NaN
df.dropna(axis=0)
# Out:
#    col1   col2 col3
# 0   1.0  555.0  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi

# %% [markdown]
# # 2. Acceso a datos

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# Pandas permite leer archivos en diferentes formatos, como txt, csv y excel. En este ejemplo se leerá un dataset correspondiente a la información nutricional de un listado de 80 cereales. El dataset puede ser descargado en el siguiente enlace (botón Downloads):
#
# https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv
#
# Como el formato es .csv, se lee usando la función de pandas read_csv usando como parámetro la dirección del archivo. Si el archivo está en la misma carpeta del notebook, se puede usar solo su nombre.

# %%
url="https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv"
df_cereals = pd.read_csv(url)

# %% [markdown]
# Si quiere conocer más formatos de entrada/salida como json, excel, hdf5, SQL, etc. Puede ir a la siguiente URL:
#
# https://pandas.pydata.org/pandas-docs/stable/io.html

# %% [markdown]
# ### Funciones para revisión de los datos
# Lo primero que haremos es revisar las propiedades que tienen las columnas del DataFrame. Como el nombre de las columnas y sus tipos:

# %%
print("Columnas: ",df_cereals.columns.tolist())
# Out:
# Columnas:  ['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating']

# %% [markdown]
# La función Info nos da un resumen del DataFrame y sus datos.

# %%
df_cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# La función dtypes sólo nos indica los tipo de datos de las columnas.

# %%
df_cereals.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# Se puede observar que Pandas es capaz de inferir el tipo de columna a partir de los datos.
#
# Para darle un vistazo inicial al DataFrame se puede utilizar la función head del DataFrame, que tiene como parámetro el número de filas que queremos observar, comenzando en orden por la primera.

# %%
df_cereals.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813

# %%
df_cereals.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %% [markdown]
# La función describe nos entrega las estadísticas descriptivas que nos permite conocer la tendencia de los datos, dispersión, dictribución, valores nulos y otros más.

# %%
df_cereals.describe(include='all')
# Out:
#              name  mfr type    calories    protein        fat      sodium  \
# count          77   77   77   77.000000  77.000000  77.000000   77.000000
# unique         77    7    2         NaN        NaN        NaN         NaN
# top     100% Bran    K    C         NaN        NaN        NaN         NaN
# freq            1   23   74         NaN        NaN        NaN         NaN
# mean          NaN  NaN  NaN  106.883117   2.545455   1.012987  159.675325
# std           NaN  NaN  NaN   19.484119   1.094790   1.006473   83.832295
# min           NaN  NaN  NaN   50.000000   1.000000   0.000000    0.000000
# 25%           NaN  NaN  NaN  100.000000   2.000000   0.000000  130.000000
# 50%           NaN  NaN  NaN  110.000000   3.000000   1.000000  180.000000
# 75%           NaN  NaN  NaN  110.000000   3.000000   2.000000  210.000000
# max           NaN  NaN  NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# count   77.000000  77.000000  77.000000   77.000000   77.000000  77.000000
# unique        NaN        NaN        NaN         NaN         NaN        NaN
# top           NaN        NaN        NaN         NaN         NaN        NaN
# freq          NaN        NaN        NaN         NaN         NaN        NaN
# mean     2.151948  14.597403   6.922078   96.077922   28.246753   2.207792
# std      2.383364   4.278956   4.444885   71.286813   22.342523   0.832524
# min      0.000000  -1.000000  -1.000000   -1.000000    0.000000   1.000000
# 25%      1.000000  12.000000   3.000000   40.000000   25.000000   1.000000
# 50%      2.000000  14.000000   7.000000   90.000000   25.000000   2.000000
# 75%      3.000000  17.000000  11.000000  120.000000   25.000000   3.000000
# max     14.000000  23.000000  15.000000  330.000000  100.000000   3.000000
#
#            weight       cups     rating
# count   77.000000  77.000000  77.000000
# unique        NaN        NaN        NaN
# top           NaN        NaN        NaN
# freq          NaN        NaN        NaN
# mean     1.029610   0.821039  42.665705
# std      0.150477   0.232716  14.047289
# min      0.500000   0.250000  18.042851
# 25%      1.000000   0.670000  33.174094
# 50%      1.000000   0.750000  40.400208
# 75%      1.000000   1.000000  50.828392
# max      1.500000   1.500000  93.704912

# %% [markdown]
# Para una descripción rápida se puede utilizar la función describe.

# %%
df_cereals['name'].unique()
# Out:
# array(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams',
#        'Grape Nuts Flakes', 'Grape-Nuts', 'Great Grains Pecan',
#        'Honey Graham Ohs', 'Honey Nut Cheerios', 'Honey-comb',
#        'Just Right Crunchy  Nuggets', 'Just Right Fruit & Nut', 'Kix',
#        'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds',
#        'Muesli Raisins; Peaches; & Pecans', 'Mueslix Crispy Blend',
#        'Multi-Grain Cheerios', 'Nut&Honey Crunch',
#        'Nutri-Grain Almond-Raisin', 'Nutri-grain Wheat',
#        'Oatmeal Raisin Crisp', 'Post Nat. Raisin Bran', 'Product 19',
#        'Puffed Rice', 'Puffed Wheat', 'Quaker Oat Squares',
#        'Quaker Oatmeal', 'Raisin Bran', 'Raisin Nut Bran',
#        'Raisin Squares', 'Rice Chex', 'Rice Krispies', 'Shredded Wheat',
#        "Shredded Wheat 'n'Bran", 'Shredded Wheat spoon size', 'Smacks',
#        'Special K', 'Strawberry Fruit Wheats', 'Total Corn Flakes',
#        'Total Raisin Bran', 'Total Whole Grain', 'Triples', 'Trix',
#        'Wheat Chex', 'Wheaties', 'Wheaties Honey Gold'], dtype=object)

# %%
df_cereals['name'].nunique()
# Out:
# 77

# %%
df_cereals['name'].value_counts()
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            1
# All-Bran                     1
# All-Bran with Extra Fiber    1
# Almond Delight               1
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 1</h1>
# </div>

# %%
# Cargar la base de datos de todos los municipios de Colombia proporcionada por el DANE
# Usar este link: https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://geoportal.dane.gov.co/descargas/divipola/DIVIPOLA_Municipios.xlsx&ved=2ahUKEwiAutK15b-LAxWHSDABHeXABdgQFnoECBgQAQ&usg=AOvVaw0ORXeyNTqYJpvXL9t1eezV

df_DANE = pd.read_excel("https://raw.githubusercontent.com/justoneye/Bootcamp-IA-G84/refs/heads/main/DataFrames/DIVIPOLA_Municipios.xlsx", skiprows=9)
df_DANE.head(20)
# Out:
#    Departamento Unnamed: 1 Municipio             Unnamed: 3  \
# 0        Código     Nombre   Código                 Nombre
# 1            05  ANTIOQUIA     05001               MEDELLÍN
# 2            05  ANTIOQUIA     05002              ABEJORRAL
# 3            05  ANTIOQUIA     05004               ABRIAQUÍ
# 4            05  ANTIOQUIA     05021             ALEJANDRÍA
# 5            05  ANTIOQUIA     05030                  AMAGÁ
# 6            05  ANTIOQUIA     05031                 AMALFI
# 7            05  ANTIOQUIA     05034                  ANDES
# 8            05  ANTIOQUIA     05036            ANGELÓPOLIS
# 9            05  ANTIOQUIA     05038              ANGOSTURA
# 10           05  ANTIOQUIA     05040                  ANORÍ
# 11           05  ANTIOQUIA     05042  SANTA FÉ DE ANTIOQUIA
# 12           05  ANTIOQUIA     05044                   ANZÁ
# 13           05  ANTIOQUIA     05045               APARTADÓ
# 14           05  ANTIOQUIA     05051              ARBOLETES
# 15           05  ANTIOQUIA     05055                ARGELIA
# 16           05  ANTIOQUIA     05059                ARMENIA
# 17           05  ANTIOQUIA     05079                BARBOSA
# 18           05  ANTIOQUIA     05086                BELMIRA
# 19           05  ANTIOQUIA     05088                  BELLO
#
#                                        Tipo Localización Unnamed: 6 Unnamed: 7
# 0   Municipio\nIsla\nÁrea no municipalizada     Longitud    Latitud       Nota
# 1                                 Municipio   -75.581775   6.246631        NaN
# 2                                 Municipio   -75.428739   5.789315        NaN
# 3                                 Municipio   -76.064304   6.632282        NaN
# 4                                 Municipio   -75.141346   6.376061        NaN
# 5                                 Municipio   -75.702188   6.038708        NaN
# 6                                 Municipio   -75.077501   6.909655        NaN
# 7                                 Municipio   -75.878828   5.657194        NaN
# 8                                 Municipio   -75.711389   6.109719        NaN
# 9                                 Municipio   -75.335116   6.885175        NaN
# 10                                Municipio   -75.148355   7.074703        NaN
# 11                                Municipio   -75.826648   6.556484        NaN
# 12                                Municipio   -75.854442   6.302641        NaN
# 13                                Municipio   -76.625279   7.882968        NaN
# 14                                Municipio   -76.426708   8.849317        NaN
# 15                                Municipio    -75.14107   5.731474        NaN
# 16                                Municipio   -75.786647   6.155667        NaN
# 17                                Municipio   -75.331627   6.439195        NaN
# 18                                Municipio   -75.667779   6.606319        NaN
# 19                                Municipio   -75.555245   6.333587        NaN

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 2</h1>
# </div>

# %%
# Cargar la base de datos de casos de Viruela del mono reportados en Colombia
# Usar este link: https://www.datos.gov.co/es/Salud-y-Protecci-n-Social/Casos-positivos-de-Viruela-s-mica-en-Colombia/tmet-yeek/about_data

df_ViruelaMono = pd.read_csv("https://raw.githubusercontent.com/justoneye/Bootcamp-IA-G84/refs/heads/main/DataFrames/Casos_positivos_de_Viruela_siimica_en_Colombia.csv")
df_ViruelaMono.head(20)
# Out:
#     Semana epidemiológica  Año epidemiológico  Código DIVIPOLA departamento  \
# 0                      22                2022                            11
# 1                      22                2022                            11
# 2                      24                2022                             5
# 3                      25                2022                            11
# 4                      26                2022                            11
# 5                      26                2022                            17
# 6                      27                2022                            11
# 7                      27                2022                            11
# 8                      27                2022                            11
# 9                      27                2022                            11
# 10                     28                2022                            11
# 11                     28                2022                            11
# 12                     28                2022                            11
# 13                     28                2022                            66
# 14                     28                2022                            11
# 15                     29                2022                            25
# 16                     29                2022                             5
# 17                     29                2022                            76
# 18                     29                2022                            11
# 19                     29                2022                            11
#
#     Código DIVIPOLA municipio  Departamento  Municipio  \
# 0                     11001.0        BOGOTA     BOGOTA
# 1                     11001.0        BOGOTA     BOGOTA
# 2                      5001.0     ANTIOQUIA   MEDELLIN
# 3                     11001.0        BOGOTA     BOGOTA
# 4                     11001.0        BOGOTA     BOGOTA
# 5                     17001.0        CALDAS  MANIZALES
# 6                     11001.0        BOGOTA     BOGOTA
# 7                     11001.0        BOGOTA     BOGOTA
# 8                     11001.0        BOGOTA     BOGOTA
# 9                     11001.0        BOGOTA     BOGOTA
# 10                    11001.0        BOGOTA     BOGOTA
# 11                    11001.0        BOGOTA     BOGOTA
# 12                    11001.0        BOGOTA     BOGOTA
# 13                    66001.0     RISARALDA    PEREIRA
# 14                    11001.0        BOGOTA     BOGOTA
# 15                    25126.0  CUNDINAMARCA     CAJICA
# 16                     5001.0     ANTIOQUIA   MEDELLIN
# 17                    76147.0         VALLE    CARTAGO
# 18                    11001.0        BOGOTA     BOGOTA
# 19                    11001.0        BOGOTA     BOGOTA
#
#          Fecha notificación        Fecha diagnóstico Sexo  Edad  ...  \
# 0   2022-06-22T00:00:00.000  2022-06-23T00:00:00.000    M    36  ...
# 1   2022-06-22T00:00:00.000  2022-06-23T00:00:00.000    M    37  ...
# 2   2022-06-21T00:00:00.000  2022-06-23T00:00:00.000    M    27  ...
# 3   2022-06-30T00:00:00.000  2022-07-01T00:00:00.000    M    31  ...
# 4   2022-06-30T00:00:00.000  2022-07-01T00:00:00.000    M    25  ...
# 5   2022-10-07T00:00:00.000  2022-10-12T00:00:00.000    M    27  ...
# 6   2022-07-06T00:00:00.000  2022-07-06T00:00:00.000    M    31  ...
# 7   2022-07-09T00:00:00.000  2022-07-09T00:00:00.000    M    34  ...
# 8   2022-07-15T00:00:00.000  2022-07-17T00:00:00.000    M    33  ...
# 9   2022-07-28T00:00:00.000  2022-07-18T00:00:00.000    F    13  ...
# 10  2022-07-16T00:00:00.000  2022-07-17T00:00:00.000    M    32  ...
# 11  2022-07-17T00:00:00.000  2022-07-18T00:00:00.000    M    26  ...
# 12  2022-07-19T00:00:00.000  2022-07-19T00:00:00.000    M    37  ...
# 13  2022-07-21T00:00:00.000  2022-07-27T00:00:00.000    M    34  ...
# 14  2022-08-17T00:00:00.000  2022-08-17T00:00:00.000    M    27  ...
# 15  2022-07-22T00:00:00.000  2022-07-23T00:00:00.000    M    41  ...
# 16  2022-07-24T00:00:00.000  2022-08-11T00:00:00.000    M    33  ...
# 17  2022-07-27T00:00:00.000  2022-07-28T00:00:00.000    M    34  ...
# 18  2022-07-27T00:00:00.000  2022-08-17T00:00:00.000    M    30  ...
# 19  2022-07-29T00:00:00.000  2022-08-18T00:00:00.000    M    25  ...
#
#     Condición final Vínculo epidemiológico ¿Viajó?  País de viaje  \
# 0                 1                      2     1.0          276.0
# 1                 1                      2     1.0          276.0
# 2                 1                      2     1.0          724.0
# 3                 1                      2     1.0          826.0
# 4                 1                      1     2.0            NaN
# 5                 1                      2     2.0            NaN
# 6                 1                      2     1.0          724.0
# 7                 1                      2     1.0          724.0
# 8                 1                      2     2.0            NaN
# 9                 1                      2     2.0            NaN
# 10                1                      2     1.0          840.0
# 11                1                      2     1.0          724.0
# 12                1                      2     1.0           76.0
# 13                1                      2     2.0            NaN
# 14                1                      2     2.0            NaN
# 15                1                      2     1.0           32.0
# 16                1                      2     2.0            NaN
# 17                1                      1     2.0            NaN
# 18                1                      2     2.0            NaN
# 19                1                      2     2.0            NaN
#
#                    Fuente de infección  Fecha de terminación del seguimiento  \
# 0                            IMPORTADO               2022-06-21T00:00:00.000
# 1                            IMPORTADO               2022-06-20T00:00:00.000
# 2                            IMPORTADO               2022-07-08T00:00:00.000
# 3                            IMPORTADO               2022-07-14T00:00:00.000
# 4       RELACIONADO CON LA IMPORTACION               2022-07-20T00:00:00.000
# 5                   FUENTE DESCONOCIDA               2022-07-22T00:00:00.000
# 6                            IMPORTADO               2022-07-24T00:00:00.000
# 7                            IMPORTADO               2022-07-28T00:00:00.000
# 8   RELACIONADO CON FUENTE DESCONOCIDA               2022-07-27T00:00:00.000
# 9                   FUENTE DESCONOCIDA               2022-07-27T00:00:00.000
# 10                           IMPORTADO               2022-08-01T00:00:00.000
# 11                           IMPORTADO               2022-08-04T00:00:00.000
# 12                           IMPORTADO               2022-08-03T00:00:00.000
# 13                  FUENTE DESCONOCIDA               2022-08-02T00:00:00.000
# 14  RELACIONADO CON FUENTE DESCONOCIDA               2022-08-04T00:00:00.000
# 15                           IMPORTADO               2022-08-09T00:00:00.000
# 16                  FUENTE DESCONOCIDA               2022-08-08T00:00:00.000
# 17  RELACIONADO CON FUENTE DESCONOCIDA               2022-08-13T00:00:00.000
# 18                  FUENTE DESCONOCIDA               2022-08-11T00:00:00.000
# 19      RELACIONADO CON LA IMPORTACION               2022-08-11T00:00:00.000
#
#     Pertenencia étnica  Nombre grupo étnico Tipo de seguridad social Estrato
# 0                    6                  NaN                        C     6.0
# 1                    6                  NaN                        C     6.0
# 2                    6                  NaN                        C   999.0
# 3                    6                  NaN                        C     4.0
# 4                    6                  NaN                        C     5.0
# 5                    6                  NaN                        S     3.0
# 6                    6                  NaN                        C     3.0
# 7                    6                  NaN                        C   999.0
# 8                    6                  NaN                        C   999.0
# 9                    6                  NaN                        I   999.0
# 10                   6                  NaN                        C     4.0
# 11                   6                  NaN                        S     3.0
# 12                   6                  NaN                        C     1.0
# 13                   6                  NaN                        C     3.0
# 14                   6                  NaN                        C     3.0
# 15                   6                  NaN                        C     6.0
# 16                   6                  NaN                        C     2.0
# 17                   6                  NaN                        C     4.0
# 18                   6                  NaN                        P     3.0
# 19                   6                  NaN                        C     2.0
#
# [20 rows x 24 columns]

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1JTvS_vjZTzQfHiMOt9ZbfqmjNN1FvOOm'>
