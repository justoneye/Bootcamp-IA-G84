# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Monitoria_2025_11_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
seleccionColombia = pd.Series(
    ['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'],
    index=[1, 2, 9, 11, 10])

display(seleccionColombia)
# Out:
# 1        Ospina
# 2        Zapata
# 9        Falcao
# 11     Cuadrado
# 10    Rodriguez
# dtype: object

# %%
meses = pd.Series(
    ['Enero', 'Marzo', 'Mayo', 'Julio', 'Septiembre','Noviembre'],
    index=[1, 3, 5, 7, 9, 11])

display(meses)
# Out:
# 1          Enero
# 3          Marzo
# 5           Mayo
# 7          Julio
# 9     Septiembre
# 11     Noviembre
# dtype: object

# %%
diccionario = {'Peru': 10, 'Colombia': 20, 'Germany': 30, 'Spain': 40, 'Japan': 0}
display(diccionario)
# Out:
# {'Peru': 10, 'Colombia': 20, 'Germany': 30, 'Spain': 40, 'Japan': 0}

# %%
diasMeses = {
    "Meses": ["Enero", "Febrero", "Marzo", "Abril"],
    "Dias": [31, 28, 31, 30]
}

df_diasMeses = pd.DataFrame(diasMeses)
display(df_diasMeses)
# Out:
#      Meses  Dias
# 0    Enero    31
# 1  Febrero    28
# 2    Marzo    31
# 3    Abril    30

# %%
dict_caracteristicas = {'apellido':['Ospina', 'Zapata', 'Falcao', 'Cuadrado', 'Rodriguez'],
                       'altura':[183.0,187.0,177.0,179.0,180.0],
                       'peso':[80.0,82.0,72.0,72.0,75.0]}

seleccionColombia = pd.DataFrame(dict_caracteristicas,index=[1, 2, 9, 11, 10])
seleccionColombia['IMC'] = seleccionColombia['peso'] / (seleccionColombia['altura'] ** 2) * 100

display(seleccionColombia)
# Out:
#      apellido  altura  peso       IMC
# 1      Ospina   183.0  80.0  0.238884
# 2      Zapata   187.0  82.0  0.234493
# 9      Falcao   177.0  72.0  0.229819
# 11   Cuadrado   179.0  72.0  0.224712
# 10  Rodriguez   180.0  75.0  0.231481

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
df.isnull()
# Out:
#     col1   col2   col3
# 0  False   True  False
# 1  False  False  False
# 2  False  False  False
# 3   True  False  False

# %%
# Eliminar filas con valores NaN
df.dropna(axis=0)
# Out:
#    col1   col2 col3
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi

# %%
url="https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv"
df_cereals = pd.read_csv(url)

df_cereals.head()
print("Columnas: ",df_cereals.columns.tolist())
df_cereals.info()
# Out:
# Columnas:  ['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB
