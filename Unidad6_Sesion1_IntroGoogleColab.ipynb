# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Unidad6_Sesion1_IntroGoogleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1nptVTliqyIIOzwF08JXJkWEvlYUC4_g5'  width="1500" height="300">

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Te damos la bienvenida a Colab</h1>
# </div>

# %% [markdown]
# Si ya conoces Colab, echa un vistazo a este vídeo para obtener información sobre las tablas interactivas, la vista del historial de código ejecutado y la paleta de comandos.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Miniatura de un vídeo que muestra tres funciones interesantes de Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>¿Qué es Google Colaboratory?</h2>
# </div>
#
# Colab, también conocido como "Colaboratory", te permite programar y ejecutar Python en tu navegador con las siguientes ventajas:
# - No requiere configuración
# - Acceso a GPUs sin coste adicional
# - Permite compartir contenido fácilmente
#
# Colab puede facilitar tu trabajo, ya seas <strong>estudiante</strong>, <strong>científico de datos</strong> o <strong>investigador de IA</strong>. No te pierdas el vídeo de <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introducción a Colab</a> para obtener más información. O simplemente empieza con los pasos descritos más abajo.

# %%
a="Hola"
print(a)
# Out:
# Hola

# %%
a='Hola'
print(a)
# Out:
# Hola

# %%
b=4
print(b)
# Out:
# 4

# %%
c={1,2,3}
print(c)
# Out:
# {1, 2, 3}

# %%
c
# Out:
# {1, 2, 3}

# %%
d=[1, 'HOLA MUNDO', {1,2,3}]
print(d)
# Out:
# [1, 'HOLA MUNDO', {1, 2, 3}]

# %%
# %whos
# Out:
# Variable          Type     Data/Info
# ------------------------------------
# a                 str      Hola
# b                 int      4
# c                 set      {1, 2, 3}
# d                 list     n=3
# edad              int      35
# horas             int      24
# minutos           int      60
# nombre            str      Pilar
# persona           list     n=3
# peso              float    60.0
# segundos          int      60
# segundos_dia      int      86400
# segundos_semana   int      604800
# semana            int      7
# src               str      imagen_DANE.png
# url               str      https://images.canal1.com<...>loads/2019/10/tabla-3.png

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 1</h1>
# </div>

# %% [markdown]
# ### Crear una variable float que guarde su peso, una variable entero que guarde su edad, un conjunto y una lista que guarde su nombre, altura, apellido.

# %%
# Escriba aquí su código!

nombre = input("Ingrese su nombre: ")
peso = float(input("Ingrese su peso: "))
edad = int(input("Ingrese su edad: "))

persona = [nombre, peso, edad]
print("\nDatos:", persona)
# Out:
# Ingrese su nombre: Pilar
# Ingrese su peso: 60
# Ingrese su edad: 35
#
# Datos: ['Pilar', 60.0, 35]

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Primeros pasos</strong>
# </div>
#
# El documento que estás leyendo no es una página web estática, sino un entorno interactivo denominado <strong>cuaderno de Colab</strong> que te permite escribir y ejecutar código.
#
# Por ejemplo, a continuación se muestra una <strong>celda de código</strong> con una breve secuencia de comandos de Python que calcula un valor, lo almacena en una variable e imprime el resultado:

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 2</h1>
# </div>

# %%
segundos = 60
minutos = 60
horas = 24
# Cuantos segundos tiene un día?
# Escriba su código aquí

segundos_dia = segundos * minutos * horas
print("Cuantos segundos tiene un día?:", segundos_dia)
# Out:
# Cuantos segundos tiene un día?: 86400

# %% [markdown]
# *Respuesta al ejercicio anterior: 86400*

# %% [markdown]
# Si quieres ejecutar el código de la celda anterior, haz clic para seleccionarlo y pulsa el botón de reproducir situado a la izquierda del código o usa la combinación de teclas "Ctrl + Enter". Para editar el código, solo tienes que hacer clic en la celda.
#
# Las variables que definas en una celda se pueden usar después en otras celdas:

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 3</h1>
# </div>

# %%
# Cuantos segundos tiene una semana?
# Escriba su código aquí

segundos = 60
minutos = 60
horas = 24
semana = 7

segundos_semana = semana * segundos * minutos * horas
print("Cuantos segundos tiene un día?:", segundos_semana)
# Out:
# Cuantos segundos tiene un día?: 604800

# %% [markdown]
# *Respuesta al ejercicio anterior: 604800*

# %% [markdown]
# Los cuadernos de Colab te permiten combinar <strong>código ejecutable</strong> y <strong>texto enriquecido</strong> en un mismo documento, además de <strong>imágenes</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> y mucho más. Los cuadernos que creas en Colab se almacenan en tu cuenta de Google Drive. Puedes compartir tus cuadernos de Colab fácilmente con compañeros de trabajo o amigos, lo que les permite comentarlos o incluso editarlos. Consulta más información en <a href="/notebooks/basic_features_overview.ipynb">Información general sobre Colab</a>. Para crear un cuaderno de Colab, puedes usar el menú Archivo que aparece arriba o bien acceder al enlace para <a href="http://colab.research.google.com#create=true">crear un cuaderno de Colab</a>.
#
# Los cuadernos de Colab son cuadernos de Jupyter alojados en Colab. Para obtener más información sobre el proyecto Jupyter, visita <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# # Celdas de Texto
#
# * Editar con **doble-click**.
#
#
#
# ---
#
#
#
# 1.   List item
# 2.   List item
#
#
# ---
#
# Explicación del ECG....
# [EEG](https://www.mayoclinic.org/es-es/tests-procedures/eeg/about/pac-20393875)
#
# ![](https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2017/10/11/14/51/bn7_eeg_results-8col.jpg)
#
#
#   * Más información al respecto [markdownguide](/notebooks/markdown_guide.ipynb).[texto del enlace](https://)
#
# 1.   Elemento de lista
#
# *   Elemento de lista
#
# ---
#
#
# *   Elemento de lista
#
#
# 2.   Elemento de lista
#
#
#
# * Las fórmulas se escriben
# $\sqrt{2x*\alpha}+(x)^2*\beta.$
#
# 5
#
# $5$
#
# **5**

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 4 - Celdas de Texto</h1>
# </div>

# %% [markdown]
# Use esta celda de texto para colocar un título, una imagen, una descripción y la Ecuación de Schrödinger dependiente del tiempo que pueden obtener en el siguiente link [Ec. de Schrodinger](https://es.wikipedia.org/wiki/Ecuaci%C3%B3n_de_Schr%C3%B6dinger).

# %% [markdown]
# ### Escriba todo en esta celda!
#
# # Ecuación de Schrödinger
#
# \begin{equation} i\hbar\frac{\partial}{\partial t}\Psi(\mathbf{r},t) = \left[-\frac{\hbar^2}{2m}\nabla^2 + V(\mathbf{r},t)\right]\Psi(\mathbf{r},t) \end{equation}
#
# ![Wave_packet_(dispersion).gif](data:image/gif;base64,...)

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Instalación de Paquetes en Colab</h1>
# </div>

# %%
import pydicom # Paquete de python para lectura y escritura de archivos médicos DICOM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1740367889.py in <cell line: 0>()
# ----> 1 import pydicom # Paquete de python para lectura y escritura de archivos médicos DICOM
#
# ModuleNotFoundError: No module named 'pydicom'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# [Pydicom](https://pypi.org/project/pydicom/)

# %%
# Instalo el paquete según la indicación de la página anterior (www.pypi.org)
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.7 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
import pydicom
import matplotlib.pyplot as plt
from pydicom import dcmread
from pydicom.data import get_testdata_file

#Cargando un archivo de Tomografía Computarizada
fpath = get_testdata_file('CT_small.dcm')
ds = dcmread(fpath)

# %%
# Graficando la información contenida en el archivo
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 5</h1>
# </div>

# %%
# Instale el paquete que falta en la siguiente linea

# %%
# Se tiene el siguiente error, instale el paquete correctamente y vuelva a correr la celda!
# !pip3 install basemap

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# set up orthographic map projection with
# perspective of satellite looking down at 45N, 100W.
# use low resolution coastlines.
map = Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')

# draw coastlines, country boundaries, fill continents.
map.drawcoastlines(linewidth=0.25)
map.drawcountries(linewidth=0.25)
map.fillcontinents(color='coral',lake_color='aqua')

# draw the edge of the map projection region (the projection limb)
map.drawmapboundary(fill_color='aqua')

# draw lat/lon grid lines every 30 degrees.
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))

# make up some data on a regular lat/lon grid.
nlats = 73; nlons = 145; delta = 2.*np.pi/(nlons-1)
lats = (0.5*np.pi-delta*np.indices((nlats,nlons))[0,:,:])
lons = (delta*np.indices((nlats,nlons))[1,:,:])
wave = 0.75*(np.sin(2.*lats)**8*np.cos(4.*lons))
mean = 0.5*np.cos(2.*lats)*((np.sin(2.*lats))**2 + 2.)

# compute native map projection coordinates of lat/lon grid.
x, y = map(lons*180./np.pi, lats*180./np.pi)

# contour data over the map.
cs = map.contour(x,y,wave+mean,15,linewidths=1.5)
plt.title('Líneas de contorno sobre fondo de continente relleno')
plt.show()
# Out:
# Requirement already satisfied: basemap in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in /usr/local/lib/python3.12/dist-packages (from basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (2.0.2)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in /usr/local/lib/python3.12/dist-packages (from basemap) (3.10.0)
# Requirement already satisfied: pyproj<3.8,>=3.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in /usr/local/lib/python3.12/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.4->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj<3.8,>=3.0->basemap) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->basemap) (1.17.0)

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 6</h1>
# </div>

# %%
# Buscar un paquete que no esté instalado en Colab e instalarlo, y correr algún ejemplo de uso con ese paquete
# Escriba su código acá:

import numpy as np
import pandas as pd

numeros = np.random.randint(1, 50, size=10)
df = pd.DataFrame(numeros, columns=['random_numbers'])

print(df)
# Out:
#    random_numbers
# 0              29
# 1              38
# 2              26
# 3              29
# 4              33
# 5              26
# 6              12
# 7              33
# 8              38
# 9               1

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 7</h1>
# </div>

# %%
# Leer imagen
url = "https://images.canal1.com.co/uploads/2019/10/tabla-3.png"
src = "imagen_DANE.png"
# !wget -q -O $src $url

# %%
# Instalar tesseract-ocr y pytesseract
# Escriba su código acá

# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
import pytesseract
from PIL import Image
extractedInformation = pytesseract.image_to_string(Image.open('/content/imagen_DANE.png'))
print(extractedInformation)
# Out:
#
#
# POBLACION AJUSTADA
# IDENTIFICACION RCOBERTU
#
# NOMBRE MUNICIPIO
#
#
#
# Medellin 2.427.129
# Barranquilla 1.206.319
# Bogota, D.C. 7.412.566
#
# Cartagena 973.045
# Tunja 172.548
#
# Manizales 434.403
#
# Florencia 168.346
#
# Popayan 318.059
# Valledupar 490.075
#
# Monteria 490.935
#
# Quibdo 129.237
#
# Neiva 357.392
#
# Riohacha 188.014
# Santa Marta 499,192
# Villavicencio 531.275
#
# Pasto 392.930
# Cdcuta 711715
# Armenia 295.208
# Pereira 467.269
# Bucaramanga 581.130
# Sincelejo 277.773
# Ibagué 529.635
# Cali 2.227.642

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 8</h1>
# </div>

# %%
# Buscar una imagen de una entidad de Cundinamarca o Boyacá y extraer la información de esa imagen
# Escriba su código acá:

import pytesseract
from PIL import Image
imagenCajica = pytesseract.image_to_string(Image.open('/content/Organigrama_Cajica.png'))
print(imagenCajica)
# Out:
# ORGANIGRAMA MUNICIPAL
#
# Ofcing sesra de Prensa
# @ esto
#
# DESPACHO DEL
# ALCALDE &
#
# G tes ce contrat interno
#
#
#
# de Control
#
#
#
# Secretaria de Gobierno:
# E erred
#
#
#
# Secretaria De Planeacion
# eT
#
# Perens)
# Desarrollo Rural
#
# To
#
# omer
# pace
# iinet)
#
#
#
# Direccién de Gestién Det
# Riesgo
#
# EG] recciones ePoica
#
# Direccién de Desarrollo
# Teritorat
#
# de Planes
# Estratégica
#
#
#
# G_vieecon nancies
#
# Direccién De Rentas,
# y Cobro Coactive,
#
# Direccign de Educacién
# Continua
#
# Direccién De Construcciones
# y Supervision,
#
# Direccién De Estudios
# y Disetios
#
#  oiecin cesta Putin
#
# Direccién de Aseguramiento,
# ‘Desarrollo y Servicios
#
# Secretaria de Desarrollo
# Ean
#
# RN
# Transporte y Movilidad
#
# ped
# Secretaria De Seguridad
# preci
# Secretaria de Desarrollo
# ery
#
# a Ofici
#
# Disciptinario Interne
#
#
#
# Direccién de EquidadY
#
# Familia
#
# Direcin de fn
# Ol vemsassgreny
#
# a Direccion de Mujer
# ‘yGénero.
#
# Direccién de Seguridad Vial
# ‘yMoulidad
#
# wing
# fan
#
# Direccion De Atencin AL
# Usuario Vl Ciudadano
#
# a

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Ciencia de datos
# </div>
#
# Con Colab, puedes aprovechar toda la potencia de las bibliotecas más populares de Python para analizar y visualizar datos. La celda de código de abajo utiliza <strong>NumPy</strong> para generar datos aleatorios y <strong>Matplotlib</strong> para visualizarlos. Para editar el código, solo tienes que hacer clic en la celda.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Sample Visualization')

# %% [markdown]
# Puedes importar tus propios datos a los cuadernos de Colab desde tu cuenta de Google Drive, incluidas las hojas de cálculo, y también desde GitHub y muchas fuentes más. Para obtener más información sobre cómo importar datos y cómo se puede usar Colab en la ciencia de datos, consulta los enlaces que aparecen en la sección <a href="#working-with-data">Trabajar con datos</a> más abajo.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Aprendizaje automático
# </div>
#
# Con Colab, puedes importar un conjunto de datos de imágenes, entrenar un clasificador de imágenes con dicho conjunto de datos y evaluar el modelo con tan solo usar unas <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">pocas líneas de código</a>. Los cuadernos de Colab ejecutan código en los servidores en la nube de Google, lo que te permite aprovechar la potencia del hardware de Google, incluidas las <a href="#using-accelerated-hardware">GPU y TPU</a>, independientemente de la potencia de tu equipo. Lo único que necesitas es un navegador.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Más recursos
#
# ### Trabajar con cuadernos en Colab
#
# </div>
#
# - [Información general sobre Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guía de Markdown](/notebooks/markdown_guide.ipynb)
# - [Importar bibliotecas e instalar dependencias](/notebooks/snippets/importing_libraries.ipynb)
# - [Guardar y cargar cuadernos en GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Formularios interactivos](/notebooks/forms.ipynb)
# - [Widgets interactivos](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Trabajar con datos
# </div>
#
# - [Cargar datos: Drive, Hojas de cálculo y Google Cloud Storage](/notebooks/io.ipynb)
# - [Gráficos: visualización de datos](/notebooks/charts.ipynb)
# - [Primeros pasos con BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Uso de hardware acelerado
# </div>
#
# - [TensorFlow con GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow con TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1JTvS_vjZTzQfHiMOt9ZbfqmjNN1FvOOm'>
