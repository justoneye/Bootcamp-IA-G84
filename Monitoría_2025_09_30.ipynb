# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Monitor%C3%ADa_2025_09_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frutas = ["banano", "manzana", "mango", "pera"]
datos=[1,2,3,4,5]

# Función lenght para saber el largo de un arreglo

print(len(frutas))
print(len(datos))

# Sentencia for para imprimir arreglo frutas

for i in range(len(frutas)):
  print(frutas[i])

# Sentencia for para imprimir arreglo de datos

for i in range(len(datos)):
  print(datos[i])
# Out:
# 4
# 5
# banano
# manzana
# mango
# pera
# 1
# 2
# 3
# 4
# 5
