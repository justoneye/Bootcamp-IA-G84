# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Unidad8_Sesion2_SeleccionColumnas_Filtros_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1nptVTliqyIIOzwF08JXJkWEvlYUC4_g5'  width="1500" height="300">

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Pandas básico</h1>
# </div>

# %% [markdown]
# # 1. Acceso a datos

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# Pandas permite leer archivos en diferentes formatos, como txt, csv y excel. En este ejemplo se leerá un dataset correspondiente a la información nutricional de un listado de 80 cereales. El dataset puede ser descargado en el siguiente enlace (botón Downloads):
#
# https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv
#
# Como el formato es .csv, se lee usando la función de pandas read_csv usando como parámetro la dirección del archivo. Si el archivo está en la misma carpeta del notebook, se puede usar solo su nombre.

# %%
import pandas as pd

url="https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv"
df_cereals = pd.read_csv(url)

# %% [markdown]
# Si quiere conocer más formatos de entrada/salida como json, excel, hdf5, SQL, etc. Puede ir a la siguiente URL:
#
# https://pandas.pydata.org/pandas-docs/stable/io.html

# %% [markdown]
# ### Funciones para revisión de los datos
# Lo primero que haremos es revisar las propiedades que tienen las columnas del DataFrame. Como el nombre de las columnas y sus tipos:

# %%
print("Columnas: ",df_cereals.columns.tolist())
# Out:
# Columnas:  ['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating']

# %% [markdown]
# La función Info nos da un resumen del DataFrame y sus datos.

# %%
df_cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# La función dtypes sólo nos indica los tipo de datos de las columnas.

# %%
df_cereals.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# Se puede observar que Pandas es capaz de inferir el tipo de columna a partir de los datos.
#
# Para darle un vistazo inicial al DataFrame se puede utilizar la función head del DataFrame, que tiene como parámetro el número de filas que queremos observar, comenzando en orden por la primera.

# %%
df_cereals.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813

# %%
df_cereals.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %% [markdown]
# La función describe nos entrega las estadísticas descriptivas que nos permite conocer la tendencia de los datos, dispersión, dictribución, valores nulos y otros más.

# %%
df_cereals.describe(include='all')
# Out:
#              name  mfr type    calories    protein        fat      sodium  \
# count          77   77   77   77.000000  77.000000  77.000000   77.000000
# unique         77    7    2         NaN        NaN        NaN         NaN
# top     100% Bran    K    C         NaN        NaN        NaN         NaN
# freq            1   23   74         NaN        NaN        NaN         NaN
# mean          NaN  NaN  NaN  106.883117   2.545455   1.012987  159.675325
# std           NaN  NaN  NaN   19.484119   1.094790   1.006473   83.832295
# min           NaN  NaN  NaN   50.000000   1.000000   0.000000    0.000000
# 25%           NaN  NaN  NaN  100.000000   2.000000   0.000000  130.000000
# 50%           NaN  NaN  NaN  110.000000   3.000000   1.000000  180.000000
# 75%           NaN  NaN  NaN  110.000000   3.000000   2.000000  210.000000
# max           NaN  NaN  NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# count   77.000000  77.000000  77.000000   77.000000   77.000000  77.000000
# unique        NaN        NaN        NaN         NaN         NaN        NaN
# top           NaN        NaN        NaN         NaN         NaN        NaN
# freq          NaN        NaN        NaN         NaN         NaN        NaN
# mean     2.151948  14.597403   6.922078   96.077922   28.246753   2.207792
# std      2.383364   4.278956   4.444885   71.286813   22.342523   0.832524
# min      0.000000  -1.000000  -1.000000   -1.000000    0.000000   1.000000
# 25%      1.000000  12.000000   3.000000   40.000000   25.000000   1.000000
# 50%      2.000000  14.000000   7.000000   90.000000   25.000000   2.000000
# 75%      3.000000  17.000000  11.000000  120.000000   25.000000   3.000000
# max     14.000000  23.000000  15.000000  330.000000  100.000000   3.000000
#
#            weight       cups     rating
# count   77.000000  77.000000  77.000000
# unique        NaN        NaN        NaN
# top           NaN        NaN        NaN
# freq          NaN        NaN        NaN
# mean     1.029610   0.821039  42.665705
# std      0.150477   0.232716  14.047289
# min      0.500000   0.250000  18.042851
# 25%      1.000000   0.670000  33.174094
# 50%      1.000000   0.750000  40.400208
# 75%      1.000000   1.000000  50.828392
# max      1.500000   1.500000  93.704912

# %% [markdown]
# Para una descripción rápida se puede utilizar la función describe.

# %%
df_cereals['name'].unique()
# Out:
# array(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams',
#        'Grape Nuts Flakes', 'Grape-Nuts', 'Great Grains Pecan',
#        'Honey Graham Ohs', 'Honey Nut Cheerios', 'Honey-comb',
#        'Just Right Crunchy  Nuggets', 'Just Right Fruit & Nut', 'Kix',
#        'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds',
#        'Muesli Raisins; Peaches; & Pecans', 'Mueslix Crispy Blend',
#        'Multi-Grain Cheerios', 'Nut&Honey Crunch',
#        'Nutri-Grain Almond-Raisin', 'Nutri-grain Wheat',
#        'Oatmeal Raisin Crisp', 'Post Nat. Raisin Bran', 'Product 19',
#        'Puffed Rice', 'Puffed Wheat', 'Quaker Oat Squares',
#        'Quaker Oatmeal', 'Raisin Bran', 'Raisin Nut Bran',
#        'Raisin Squares', 'Rice Chex', 'Rice Krispies', 'Shredded Wheat',
#        "Shredded Wheat 'n'Bran", 'Shredded Wheat spoon size', 'Smacks',
#        'Special K', 'Strawberry Fruit Wheats', 'Total Corn Flakes',
#        'Total Raisin Bran', 'Total Whole Grain', 'Triples', 'Trix',
#        'Wheat Chex', 'Wheaties', 'Wheaties Honey Gold'], dtype=object)

# %%
df_cereals['name'].nunique()
# Out:
# 77

# %%
df_cereals['name'].value_counts()
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            1
# All-Bran                     1
# All-Bran with Extra Fiber    1
# Almond Delight               1
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# ## Indexación
# En Pandas la indexación es similar a la que se tiene en Numpy. El resultado de obtener resultados por indexación es otro DataFrame correspondiente a ciertas filas del DataFrame original.
#
# ### Obtención de filas por índice
# Un ejemplo es acceder a una fila por medio de la función iloc. En la siguiente celda se selecciona el cereal con índice 7.

# %%
df_cereals.iloc[7]
# Out:
# name          Basic 4
# mfr                 G
# type                C
# calories          130
# protein             3
# fat                 2
# sodium            210
# fiber             2.0
# carbo            18.0
# sugars              8
# potass            100
# vitamins           25
# shelf               3
# weight           1.33
# cups             0.75
# rating      37.038562
# Name: 7, dtype: object

# %% [markdown]
# ### Obtención de valores por columna
# Para obtener toda la información de una columna, se puede acceder al DataFrame como un diccionario, en donde la llave es la columna a la que queremos acceder.

# %%
info_calories = df_cereals['calories']

# %% [markdown]
# Veamos que si usamos el acceso con un corchete cuadrado, nos retorna un objeto tipo series.

# %%
type(info_calories)
# Out:
# pandas.core.series.Series

# %% [markdown]
# En cambio si usamos doble corchete, nos retorna un dataframe con la columna.

# %%
type(df_cereals[['calories']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# La información de columna se obtiene en el mismo orden que en el DataFrame original. Al imprimirlo, podemos ver en la primera columna el valor del índice y en la segunda el valor de la columna seleccionada.

# %%
print(info_calories[0:10])
# Out:
# 0     70
# 1    120
# 2     70
# 3     50
# 4    110
# 5    110
# 6    110
# 7    130
# 8     90
# 9     90
# Name: calories, dtype: int64

# %% [markdown]
# Se pueden seleccionar más de una columna del DataFrame a la vez.

# %%
df_cereals[['calories','sugars']]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %% [markdown]
# ### Obtención de valores usando condiciones
# Con Pandas, se pueden seleccionar columnas cuyas características cumplan ciertas condiciones. Por ejemplo, los cereales con menos de 100 calorias. Para ello se hace la selección de la columna, se evalua la condición con esta y luego se selecciona del DataFrame el segmento que cumple la condición de la siguiente manera:

# %%
#Seleccion de columna: df_cereals['calories']
#Condicion sobre esa columna: df_cereals['calories'] < 100
#Seleccion de fragmento de dataframe que cumple la condicion:
    #df_cereals[df_cereals['calories'] < 100]
df_cereals[df_cereals['calories'] < 100]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 8                   Bran Chex   R    C        90        2    1     200    4.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 50          Nutri-grain Wheat   K    C        90        3    0     170    3.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3    1.00  0.33  68.402973
# 2     7.0       5     320        25      3    1.00  0.33  59.425505
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 8    15.0       6     125        25      1    1.00  0.67  49.120253
# 9    13.0       5     190        25      3    1.00  0.67  53.313813
# 50   18.0       2      90        25      3    1.00  1.00  59.642837
# 54   13.0       0      15         0      3    0.50  1.00  60.756112
# 55   10.0       0      50         0      3    0.50  1.00  63.005645
# 60   15.0       6     110        25      3    1.00  0.50  55.333142
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %% [markdown]
# Las condiciones se pueden mezclar usando operadores lógicos, por ejemplo cereales con menos de 100 calorias y sin grasa (valor 0 en fat).

# %%
condition_calories = df_cereals['calories'] < 100
condition_fat = df_cereals['fat'] == 0
menos_100_cal_and_fat = df_cereals[condition_calories & condition_fat]

# %%
menos_100_cal_and_fat.describe()
# Out:
#         calories    protein   fat      sodium      fiber      carbo  \
# count  10.000000  10.000000  10.0   10.000000  10.000000  10.000000
# mean   77.000000   2.500000   0.0   53.500000   3.800000  14.700000
# std    18.885621   0.849837   0.0   84.460707   3.852849   3.831159
# min    50.000000   1.000000   0.0    0.000000   0.000000   8.000000
# 25%    57.500000   2.000000   0.0    0.000000   2.250000  13.000000
# 50%    90.000000   2.500000   0.0    0.000000   3.000000  15.000000
# 75%    90.000000   3.000000   0.0  108.750000   3.750000  17.500000
# max    90.000000   4.000000   0.0  210.000000  14.000000  20.000000
#
#           sugars     potass   vitamins      shelf     weight       cups  \
# count  10.000000   10.00000  10.000000  10.000000  10.000000  10.000000
# mean    1.800000  123.00000  12.500000   2.300000   0.883000   0.801000
# std     2.529822   86.76917  13.176157   0.948683   0.208702   0.218757
# min     0.000000   15.00000   0.000000   1.000000   0.500000   0.500000
# 25%     0.000000   90.00000   0.000000   1.250000   0.872500   0.670000
# 50%     0.000000  102.50000  12.500000   3.000000   1.000000   0.835000
# 75%     4.250000  135.00000  25.000000   3.000000   1.000000   1.000000
# max     6.000000  330.00000  25.000000   3.000000   1.000000   1.000000
#
#           rating
# count  10.000000
# mean   66.063108
# std    11.954602
# min    53.313813
# 25%    59.433704
# 50%    61.880879
# 75%    71.660312
# max    93.704912

# %% [markdown]
# Teniendo en cuenta que el resultado de la indexación también es un DataFrame, se pueden hacer operaciones similares sobre el resultado, que en este caso tiene el identificador less_100_cal_and_fat.

# %%
menos_100_cal_and_fat.head(10)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 50          Nutri-grain Wheat   K    C        90        3    0     170    3.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 68    Strawberry Fruit Wheats   N    C        90        2    0      15    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 9    13.0       5     190        25      3    1.00  0.67  53.313813
# 50   18.0       2      90        25      3    1.00  1.00  59.642837
# 54   13.0       0      15         0      3    0.50  1.00  60.756112
# 55   10.0       0      50         0      3    0.50  1.00  63.005645
# 60   15.0       6     110        25      3    1.00  0.50  55.333142
# 63   16.0       0      95         0      1    0.83  1.00  68.235885
# 64   19.0       0     140         0      1    1.00  0.67  74.472949
# 65   20.0       0     120         0      1    1.00  0.67  72.801787
# 68   15.0       5      90        25      2    1.00  1.00  59.363993

# %% [markdown]
# ### Ejemplos de operaciones sobre DataFrames

# %% [markdown]
# Como se vio al usar la función describe, con el DataFrame se pueden hacer operaciones matemáticas, como hallar la media y desviación estándar. En este caso vamos a hallar la media de calificaciones de los cereales que tienen menos de 100 calorias y no tienen grasa. La operación de media se calcula sobre todas las columnas.

# %%
menos_100_cal_and_fat.loc[:,'calories':'rating'].mean()
# Out:
# calories     77.000000
# protein       2.500000
# fat           0.000000
# sodium       53.500000
# fiber         3.800000
# carbo        14.700000
# sugars        1.800000
# potass      123.000000
# vitamins     12.500000
# shelf         2.300000
# weight        0.883000
# cups          0.801000
# rating       66.063108
# dtype: float64

# %% [markdown]
# La desviación estándar sobre el rating se puede calcular de la siguiente manera.

# %%
menos_100_cal_and_fat.loc[:,'calories':'rating'].std()
# Out:
# calories    18.885621
# protein      0.849837
# fat          0.000000
# sodium      84.460707
# fiber        3.852849
# carbo        3.831159
# sugars       2.529822
# potass      86.769170
# vitamins    13.176157
# shelf        0.948683
# weight       0.208702
# cups         0.218757
# rating      11.954602
# dtype: float64

# %% [markdown]
# ### Multi-Indices
#
# Los dataframes pueden tener varios índices usando la funcionalidad de MultiIndex. Estos se pueden crear a partir de una lista de tuplas, con el método from_tuples, donde cada tupla contiene los nombres de cada columna o a partir de una combinación entre varias tuplas con el método from_product

# %%
columns = pd.MultiIndex.from_tuples([('A', 'positivo'), ('B', 'positivo'),
                                     ('A', 'negativo'), ('B', 'negativo'),
                                     ('O', 'positivo')],
                                     names=['tipo', 'Rh'])

# %%
columns
# Out:
# MultiIndex([('A', 'positivo'),
#             ('B', 'positivo'),
#             ('A', 'negativo'),
#             ('B', 'negativo'),
#             ('O', 'positivo')],
#            names=['tipo', 'Rh'])

# %% [markdown]
# Ahora se crea el Indice

# %%
import numpy as np
index = pd.MultiIndex.from_product([('menor', 'adulto'),('hombre', 'mujer')],
                                   names=['edad', 'sexo'])
df = pd.DataFrame(np.random.randn(4,5), columns=columns, index=index)
df
# Out:
# tipo                  A         B         A         B         O
# Rh             positivo  positivo  negativo  negativo  positivo
# edad   sexo
# menor  hombre  0.090662 -1.631023 -2.087178 -0.927347  0.647180
#        mujer  -0.780061 -0.985397  0.104213 -1.723247 -1.064033
# adulto hombre  0.873263  0.760651  0.288461  1.778607  2.632245
#        mujer  -0.806204 -1.365231  0.180875  0.689946  0.694878

# %% [markdown]
# Para obtener información de las columnas de otros niveles, se debe referir primero la columna de primer nivel y luego a las de los niveles siguientes, en órden jerárquico.

# %%
df['B', 'positivo']
# Out:
# edad    sexo
# menor   hombre   -1.631023
#         mujer    -0.985397
# adulto  hombre    0.760651
#         mujer    -1.365231
# Name: (B, positivo), dtype: float64

# %% [markdown]
# La función 'xs' (cross-section) retorna la sección transversal de un DataFrame que usa multi-índices.
# Por ejemplo, es útil cuando queremos filtrar todos los elementos de un determinado "sexo" en el DataFrame anterior, independientemente de su "edad".

# %%
# En este caso seleccionamos el Num=1
df.xs('hombre',level='sexo')
# Out:
# tipo           A         B         A         B         O
# Rh      positivo  positivo  negativo  negativo  positivo
# edad
# menor   0.090662 -1.631023 -2.087178 -0.927347  0.647180
# adulto  0.873263  0.760651  0.288461  1.778607  2.632245

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# Pandas permite leer archivos en diferentes formatos, como txt, csv y excel. En este ejemplo se leerá un dataset correspondiente a la información nutricional de un listado de 80 cereales. El dataset puede ser descargado en el siguiente enlace (botón Downloads):
#
# https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv
#
# Como el formato es .csv, se lee usando la función de pandas read_csv usando como parámetro la dirección del archivo. Si el archivo está en la misma carpeta del notebook, se puede usar solo su nombre.

# %%
url="https://raw.githubusercontent.com/AYPenchev/80-Cereals/refs/heads/master/cereal.csv"
df_cereals = pd.read_csv(url)

# %% [markdown]
# Si quiere conocer más formatos de entrada/salida como json, excel, hdf5, SQL, etc. Puede ir a la siguiente URL:
#
# https://pandas.pydata.org/pandas-docs/stable/io.html

# %% [markdown]
# ### Funciones para revisión de los datos
# Lo primero que haremos es revisar las propiedades que tienen las columnas del DataFrame. Como el nombre de las columnas y sus tipos:

# %%
print("Columnas: ",df_cereals.columns.tolist())
# Out:
# Columnas:  ['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating']

# %% [markdown]
# La función Info nos da un resumen del DataFrame y sus datos.

# %%
df_cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %% [markdown]
# La función dtypes sólo nos indica los tipo de datos de las columnas.

# %%
df_cereals.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# Se puede observar que Pandas es capaz de inferir el tipo de columna a partir de los datos.
#
# Para darle un vistazo inicial al DataFrame se puede utilizar la función head del DataFrame, que tiene como parámetro el número de filas que queremos observar, comenzando en orden por la primera.

# %%
df_cereals.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3    1.00  0.33  68.402973
# 1    8.0       8     135         0      3    1.00  1.00  33.983679
# 2    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    8.0       0     330        25      3    1.00  0.50  93.704912
# 4   14.0       8      -1        25      3    1.00  0.75  34.384843
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813

# %%
df_cereals.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %% [markdown]
# La función describe nos entrega las estadísticas descriptivas que nos permite conocer la tendencia de los datos, dispersión, dictribución, valores nulos y otros más.

# %%
df_cereals.describe(include='all')
# Out:
#              name  mfr type    calories    protein        fat      sodium  \
# count          77   77   77   77.000000  77.000000  77.000000   77.000000
# unique         77    7    2         NaN        NaN        NaN         NaN
# top     100% Bran    K    C         NaN        NaN        NaN         NaN
# freq            1   23   74         NaN        NaN        NaN         NaN
# mean          NaN  NaN  NaN  106.883117   2.545455   1.012987  159.675325
# std           NaN  NaN  NaN   19.484119   1.094790   1.006473   83.832295
# min           NaN  NaN  NaN   50.000000   1.000000   0.000000    0.000000
# 25%           NaN  NaN  NaN  100.000000   2.000000   0.000000  130.000000
# 50%           NaN  NaN  NaN  110.000000   3.000000   1.000000  180.000000
# 75%           NaN  NaN  NaN  110.000000   3.000000   2.000000  210.000000
# max           NaN  NaN  NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# count   77.000000  77.000000  77.000000   77.000000   77.000000  77.000000
# unique        NaN        NaN        NaN         NaN         NaN        NaN
# top           NaN        NaN        NaN         NaN         NaN        NaN
# freq          NaN        NaN        NaN         NaN         NaN        NaN
# mean     2.151948  14.597403   6.922078   96.077922   28.246753   2.207792
# std      2.383364   4.278956   4.444885   71.286813   22.342523   0.832524
# min      0.000000  -1.000000  -1.000000   -1.000000    0.000000   1.000000
# 25%      1.000000  12.000000   3.000000   40.000000   25.000000   1.000000
# 50%      2.000000  14.000000   7.000000   90.000000   25.000000   2.000000
# 75%      3.000000  17.000000  11.000000  120.000000   25.000000   3.000000
# max     14.000000  23.000000  15.000000  330.000000  100.000000   3.000000
#
#            weight       cups     rating
# count   77.000000  77.000000  77.000000
# unique        NaN        NaN        NaN
# top           NaN        NaN        NaN
# freq          NaN        NaN        NaN
# mean     1.029610   0.821039  42.665705
# std      0.150477   0.232716  14.047289
# min      0.500000   0.250000  18.042851
# 25%      1.000000   0.670000  33.174094
# 50%      1.000000   0.750000  40.400208
# 75%      1.000000   1.000000  50.828392
# max      1.500000   1.500000  93.704912

# %% [markdown]
# Para una descripción rápida se puede utilizar la función describe.

# %%
df_cereals['name'].unique()
# Out:
# array(['100% Bran', '100% Natural Bran', 'All-Bran',
#        'All-Bran with Extra Fiber', 'Almond Delight',
#        'Apple Cinnamon Cheerios', 'Apple Jacks', 'Basic 4', 'Bran Chex',
#        'Bran Flakes', "Cap'n'Crunch", 'Cheerios', 'Cinnamon Toast Crunch',
#        'Clusters', 'Cocoa Puffs', 'Corn Chex', 'Corn Flakes', 'Corn Pops',
#        'Count Chocula', "Cracklin' Oat Bran", 'Cream of Wheat (Quick)',
#        'Crispix', 'Crispy Wheat & Raisins', 'Double Chex', 'Froot Loops',
#        'Frosted Flakes', 'Frosted Mini-Wheats',
#        'Fruit & Fibre Dates; Walnuts; and Oats', 'Fruitful Bran',
#        'Fruity Pebbles', 'Golden Crisp', 'Golden Grahams',
#        'Grape Nuts Flakes', 'Grape-Nuts', 'Great Grains Pecan',
#        'Honey Graham Ohs', 'Honey Nut Cheerios', 'Honey-comb',
#        'Just Right Crunchy  Nuggets', 'Just Right Fruit & Nut', 'Kix',
#        'Life', 'Lucky Charms', 'Maypo',
#        'Muesli Raisins; Dates; & Almonds',
#        'Muesli Raisins; Peaches; & Pecans', 'Mueslix Crispy Blend',
#        'Multi-Grain Cheerios', 'Nut&Honey Crunch',
#        'Nutri-Grain Almond-Raisin', 'Nutri-grain Wheat',
#        'Oatmeal Raisin Crisp', 'Post Nat. Raisin Bran', 'Product 19',
#        'Puffed Rice', 'Puffed Wheat', 'Quaker Oat Squares',
#        'Quaker Oatmeal', 'Raisin Bran', 'Raisin Nut Bran',
#        'Raisin Squares', 'Rice Chex', 'Rice Krispies', 'Shredded Wheat',
#        "Shredded Wheat 'n'Bran", 'Shredded Wheat spoon size', 'Smacks',
#        'Special K', 'Strawberry Fruit Wheats', 'Total Corn Flakes',
#        'Total Raisin Bran', 'Total Whole Grain', 'Triples', 'Trix',
#        'Wheat Chex', 'Wheaties', 'Wheaties Honey Gold'], dtype=object)

# %%
df_cereals['name'].nunique()
# Out:
# 77

# %%
df_cereals['name'].value_counts()
# Out:
# name
# 100% Bran                    1
# 100% Natural Bran            1
# All-Bran                     1
# All-Bran with Extra Fiber    1
# Almond Delight               1
#                             ..
# Triples                      1
# Trix                         1
# Wheat Chex                   1
# Wheaties                     1
# Wheaties Honey Gold          1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 1</h1>
# </div>

# %%
# Realizar filtrado por filas y columnas con la base de datos de todos los municipios de Colombia proporcionada por el DANE
# Usar este link: https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://geoportal.dane.gov.co/descargas/divipola/DIVIPOLA_Municipios.xlsx&ved=2ahUKEwiAutK15b-LAxWHSDABHeXABdgQFnoECBgQAQ&usg=AOvVaw0ORXeyNTqYJpvXL9t1eezV

df_DANE = pd.read_excel("https://raw.githubusercontent.com/justoneye/Bootcamp-IA-G84/refs/heads/main/DataFrames/DIVIPOLA_Municipios.xlsx", skiprows=10, nrows=1123)

df_DANE.info()
df_DANE.dtypes
df_DANE.head(15)

# VMostrar Cundinamarca
filtroCUND = df_DANE['Nombre_Departamento'] == 'CUNDINAMARCA'
filtroCUND.head(15)

# Vista de municipios
municipios = df_DANE[['Nombre_Departamento', 'Nombre_Municipio']]
municipios.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Código_Departamento  1122 non-null   int64
#  1   Nombre_Departamento  1122 non-null   object
#  2   Código_Municipio     1122 non-null   int64
#  3   Nombre_Municipio     1122 non-null   object
#  4   Tipo                 1122 non-null   object
#  5   Longitud             1122 non-null   float64
#  6   Latitud              1122 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 61.5+ KB
#    Nombre_Departamento       Nombre_Municipio
# 0            ANTIOQUIA               MEDELLÍN
# 1            ANTIOQUIA              ABEJORRAL
# 2            ANTIOQUIA               ABRIAQUÍ
# 3            ANTIOQUIA             ALEJANDRÍA
# 4            ANTIOQUIA                  AMAGÁ
# 5            ANTIOQUIA                 AMALFI
# 6            ANTIOQUIA                  ANDES
# 7            ANTIOQUIA            ANGELÓPOLIS
# 8            ANTIOQUIA              ANGOSTURA
# 9            ANTIOQUIA                  ANORÍ
# 10           ANTIOQUIA  SANTA FÉ DE ANTIOQUIA
# 11           ANTIOQUIA                   ANZÁ
# 12           ANTIOQUIA               APARTADÓ
# 13           ANTIOQUIA              ARBOLETES
# 14           ANTIOQUIA                ARGELIA

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 2</h1>
# </div>

# %%
# Realizar filtrado por filas y columnas con la base de datos de casos de Viruela del mono reportados en Colombia
# Usar este link: https://www.datos.gov.co/es/Salud-y-Protecci-n-Social/Casos-positivos-de-Viruela-s-mica-en-Colombia/tmet-yeek/about_data

df_ViruelaMono = pd.read_csv("https://raw.githubusercontent.com/justoneye/Bootcamp-IA-G84/refs/heads/main/DataFrames/Casos_positivos_de_Viruela_siimica_en_Colombia.csv")


filtroAnyo = df_ViruelaMono['Año epidemiológico'] >= 2024
filtroDep = df_ViruelaMono['Departamento'] == 'CUNDINAMARCA'
filtroCasos = df_ViruelaMono[filtroAnyo & filtroDep]
filtroCasos.head(15)
# Out:
#       Semana epidemiológica  Año epidemiológico  Código DIVIPOLA departamento  \
# 4159                      2                2024                            25
# 4175                      4                2024                            25
# 4176                      4                2024                            25
# 4193                      8                2024                            25
# 4482                     40                2025                            25
# 4489                     41                2025                            25
# 4496                     40                2025                            25
# 4509                     41                2025                            25
# 4515                     41                2025                            25
#
#       Código DIVIPOLA municipio  Departamento  Municipio  \
# 4159                    25754.0  CUNDINAMARCA     SOACHA
# 4175                    25175.0  CUNDINAMARCA       CHIA
# 4176                    25377.0  CUNDINAMARCA  LA CALERA
# 4193                    25754.0  CUNDINAMARCA     SOACHA
# 4482                    25754.0  CUNDINAMARCA     SOACHA
# 4489                    25754.0  CUNDINAMARCA     SOACHA
# 4496                    25754.0  CUNDINAMARCA     SOACHA
# 4509                    25754.0  CUNDINAMARCA     SOACHA
# 4515                    25754.0  CUNDINAMARCA     SOACHA
#
#            Fecha notificación        Fecha diagnóstico Sexo  Edad  ...  \
# 4159  2024-01-11T00:00:00.000  2024-01-11T00:00:00.000    M    30  ...
# 4175  2024-01-31T00:00:00.000  2024-01-31T00:00:00.000    M    30  ...
# 4176  2024-01-31T00:00:00.000  2024-02-01T00:00:00.000    M    45  ...
# 4193  2024-02-28T00:00:00.000  2024-02-28T00:00:00.000    M    30  ...
# 4482  2025-10-07T00:00:00.000  2025-10-09T00:00:00.000    M    51  ...
# 4489  2025-10-10T00:00:00.000  2025-10-14T00:00:00.000    M    33  ...
# 4496               2025-10-10               2025-10-21    M    25  ...
# 4509               2025-10-16               2025-10-21    M    44  ...
# 4515               2025-10-13               2025-10-16    M    36  ...
#
#       Condición final Vínculo epidemiológico ¿Viajó?  País de viaje  \
# 4159                1                      2     2.0            NaN
# 4175                1                      2     2.0            NaN
# 4176                1                      1     2.0            NaN
# 4193                1                      2     2.0            NaN
# 4482                1                      2     2.0            NaN
# 4489                1                      2     2.0            NaN
# 4496                1                      2     2.0            NaN
# 4509                1                      1     2.0            NaN
# 4515                1                      3     2.0            NaN
#
#       Fuente de infección  Fecha de terminación del seguimiento  \
# 4159           EN ESTUDIO               2024-01-28T00:00:00.000
# 4175           EN ESTUDIO               2024-02-12T00:00:00.000
# 4176           EN ESTUDIO               2024-02-14T00:00:00.000
# 4193           EN ESTUDIO               2024-03-16T00:00:00.000
# 4482   FUENTE DESCONOCIDA               2025-10-23T00:00:00.000
# 4489           EN ESTUDIO               2025-10-27T00:00:00.000
# 4496           EN ESTUDIO                            2025-10-24
# 4509           EN ESTUDIO                            2025-10-30
# 4515   FUENTE DESCONOCIDA                            2025-10-29
#
#       Pertenencia étnica  Nombre grupo étnico Tipo de seguridad social Estrato
# 4159                   6                  NaN                        C     2.0
# 4175                   6                  NaN                        C     2.0
# 4176                   6                  NaN                        C     4.0
# 4193                   6                  NaN                        C     3.0
# 4482                   6                  NaN                        C     3.0
# 4489                   6                  NaN                        C     2.0
# 4496                   6                  NaN                        C     2.0
# 4509                   6                  NaN                        C     4.0
# 4515                   6                  NaN                        P     3.0
#
# [9 rows x 24 columns]

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1JTvS_vjZTzQfHiMOt9ZbfqmjNN1FvOOm'>
