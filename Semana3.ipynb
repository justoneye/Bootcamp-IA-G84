# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Semana3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Función para número par
def par(num):
  if (num % 2 == False):
    return "El número es PAR"
  else:
    return "El número es IMPAR"



# Función para número primo
def primo(num):
  primo = True
  divisores = 0
  respuesta = ""

  for i in range(2, num-1):
      if (num % i == 0 and divisores == 0):
          respuesta = "El numero NO es PRIMO"
          divisores+=1

  if (divisores == 0):
      respuesta = "El numero es PRIMO"

  return respuesta



# Función para ejecutar el menú inicial
def main():
    numero = int(input("Ingrese número: "))
    print("\n\n", "MENÚ: Saber si un número es:\n   1: Par o Impar\n   2: Primo\n   3: SALIR.\n")
    opcion = ""

    while (opcion!="3"):
        opcion = input("Ingrese la opción correspondiente: ")

        if opcion=="1":
            print(par(numero), "\n")

        elif opcion=="2":
            print(primo(numero), "\n")

        elif opcion=="3":
            print("--- FIN ---")
        else:
            print("Opción incorrecta, ingresa una opción válida nuevamente.\n\n")

main()
# Out:
# Ingrese número: 7
#
#
#  MENÚ: Saber si un número es:
#    1: Par o Impar
#    2: Primo
#    3: SALIR.
#
# Ingrese la opción correspondiente: 1
# El número es IMPAR
#
# Ingrese la opción correspondiente: 2
# El numero es PRIMO
#
# Ingrese la opción correspondiente: 4
# Opción incorrecta, ingresa una opción válida nuevamente.
# Ingrese la opción correspondiente: 3
# --- FIN ---

# %%
'''
Crear un menú con las siguientes opciones:
  1. Calcular el área de un cuadrado
  2. Calcular el área de un círculo
  3. Calcular el área de un rectángulo
  4. Salir
'''

import math

# Función para área de un cuadrado
def cuadrado(lado):
  lado = int(input("Ingrese la medida del lado del cuadrado (sin unidades): "))
  resultado = print("El área del cuadrado es", lado ** 2, " unidades")
  return resultado


# Función para área de un círculo
def circulo(radio):
  radio = float(input("Ingrese el radio del círculo (sin unidades): "))
  resultado = print("El área del cuadrado es", (math.pi * radio ** 2), " unidades")
  return resultado


# Función para área de un rectangulo
def rectangulo(alto, ancho):
  alto = int(input("Ingrese el alto del rectángulo (sin unidades): "))
  ancho  = int(input("Ingrese el ancho del rectángulo (sin unidades): "))
  resultado = print("El área del cuadrado es", (alto * ancho), " unidades")
  return resultado



# Función para ejecutar el menú inicial
def main():
    print("\n\n", "MENÚ: \n 1. Calcular el área de un cuadrado. \n 2. Calcular el área de un círculo. \n 3. Calcular el área de un rectángulo. \n 4. SALIR.\n")
    opcion = ""
    alto = ""
    ancho = ""

    while (opcion!="4"):
        opcion = input("Ingrese la opción correspondiente: ")

        if opcion=="1":
            print(cuadrado(alto), "\n")

        elif opcion=="2":
            print(circulo(alto), "\n")

        elif opcion=="3":
            print(rectangulo(alto, ancho), "\n")

        elif opcion=="4":
            print("SALIR. Adiós.")
        else:
            print("Opción incorrecta, ingresa una opción válida nuevamente.\n\n")

main()
# Out:
#  MENÚ:
#  1. Calcular el área de un cuadrado.
#  2. Calcular el área de un círculo.
#  3. Calcular el área de un rectángulo.
#  4. SALIR.
#
# Ingrese la opción correspondiente: 1
# Ingrese la medida del lado del cuadrado (sin unidades): 12
# El área del cuadrado es 144  unidades
# None
#
# Ingrese la opción correspondiente: 2
# Ingrese el radio del círculo (sin unidades): 3
# El área del cuadrado es 28.274333882308138  unidades
# None
#
# Ingrese la opción correspondiente: 3
# Ingrese el alto del rectángulo (sin unidades): 3
# Ingrese el ancho del rectángulo (sin unidades): 4
# El área del cuadrado es 12  unidades
# None
#
# Ingrese la opción correspondiente: g
# Opción incorrecta, ingresa una opción válida nuevamente.
#
#
# Ingrese la opción correspondiente: 4
# SALIR. Adiós.

# %%
'''
Crear un programa que:
1. Adicionar una venta
2. Mostrar el promedio de ventas
3. Salir
'''

def main():
  menu = "\n\nMENÚ: \n 1. Adicionar una venta. \n 2. Mostrar el promedio de ventas. \n 3. Salir del programa.\n\nPor favor ingrese la opción que desee:"
  opc = ""
  ventas = []

  while opc!="3":
    print(menu)
    opc = input()

    if opc=="1":
      venta = float(input("Ingrese la nueva venta: $"))
      ventas.append(venta)
      print("\nNueva venta adicionada. En total hay", len(ventas), "ventas registradas.")

    elif opc=="2":
      sumaVentas = 0.0

      for i in range (len(ventas)):
        sumaVentas = sumaVentas + ventas[i]
      sumaVentas = sumaVentas / len(ventas)
      print("El promedio de las ventas es: $", sumaVentas, "\n")
    elif opc=="3":
      print("--- Programa finalizado. Gracias.")
    else:
      print("La opción es incorrecta, por favor inténtelo nuevamente\n\n")

main()
# Out:
# MENÚ:
#  1. Adicionar una venta.
#  2. Mostrar el promedio de ventas.
#  3. Salir del programa.
#
# Por favor ingrese la opción que desee:
# 1
# Ingrese la nueva venta: $123
#
# Nueva venta adicionada. En total hay 1 ventas registradas.
#
#
# MENÚ:
#  1. Adicionar una venta.
#  2. Mostrar el promedio de ventas.
#  3. Salir del programa.
#
# Por favor ingrese la opción que desee:
# 1
# Ingrese la nueva venta: $123
#
# Nueva venta adicionada. En total hay 2 ventas registradas.
#
#
# MENÚ:
#  1. Adicionar una venta.
#  2. Mostrar el promedio de ventas.
#  3. Salir del programa.
#
# Por favor ingrese la opción que desee:
# 1
# Ingrese la nueva venta: $123
#
# Nueva venta adicionada. En total hay 3 ventas registradas.
#
#
# MENÚ:
#  1. Adicionar una venta.
#  2. Mostrar el promedio de ventas.
#  3. Salir del programa.
#
# Por favor ingrese la opción que desee:
# 2
# El promedio de las ventas es: $ 123.0
#
#
#
# MENÚ:
#  1. Adicionar una venta.
#  2. Mostrar el promedio de ventas.
# ...
