# %% [markdown]
# <a href="https://colab.research.google.com/github/justoneye/Bootcamp-IA-G84/blob/main/Unidad7_Sesion3_Cadenas_Condicionales_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1nptVTliqyIIOzwF08JXJkWEvlYUC4_g5'  width="1500" height="300">

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Cadenas en Python</h1>
# </div>

# %% [markdown]
# Las cadenas se utilizan para almacenar texto. Se pueden delimitar mediante comillas simples o dobles.

# %%
cadena1 = "Hola Mundo"
cadena2 = 'Hola a todos'
print(cadena1, cadena2)
# Out:
# Hola Mundo Hola a todos

# %% [markdown]
# Podemos acceder a un elemento o a un conjunto de elementos de una cadena:

# %%
cadena1[3]
# Out:
# 'a'

# %%
cadena1[5:]

# %% [markdown]
# Con el operador +, podemos unir o concatenar dos o más cadenas:

# %%
cadena1 + " , " + cadena2
# Out:
# 'Hola Mundo , Hola a todos'

# %% [markdown]
# ## Condicionales

# %% [markdown]
# Los condicionales son una forma de ejecutar código dependiendo de si una condición es Verdadera o Falso. Al igual que en otros lenguajes, Python admite if y else, pero else if se contrae a elif, como lo demuestra el siguiente ejemplo.

# %%
# Correr la siguiente linea 3 veces, con un número positivo, otro negativo y con 0
numero = int(input('Ingrese un número entre -10 y 10 '))
if numero < 0:
  print("negativo")
elif numero == 0:
  print("nulo")
else: # numero > 0
  print("positivo")
# Out:
# Ingrese un número entre -10 y 10 -8
# negativo

# %% [markdown]
# ## Bucles

# %% [markdown]
# Los bucles son una forma de ejecutar un bloque de código varias veces. Hay dos tipos principales de bucles: bucles while y bucles for.

# %%
lista = [1, 2, 3]

# %% [markdown]
# Usando while

# %%
i = 0
while i < len(lista):
  print(lista[i])
  i += 1 # equivalente a i = i + 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# Usando for

# %%
for i in range(len(lista)):
  print(lista[i])
# Out:
# 1
# 2
# 3

# %% [markdown]
# De otra forma:

# %%
for element in lista:
  print(element)
# Out:
# 1
# 2
# 3

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 1</h1>
# </div>

# %% [markdown]
# Usar un condicional para definir la función [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) que tiene la siguiente fórmula:
#
# $\text{relu}(x) = \left\{
#    \begin{array}{rl}
#      x, & \text{if }  x \ge 0 \\
#      0, & \text{otherwise }.
#    \end{array}\right.$

# %%
# Escriba aquí su código

x = int(input("Ingrese un número: "))

if x >= 0:
  print("relu(x) =", x)
else: # x < 0
  print("relu(x) =", 0)
# Out:
# Ingrese un número: 0
# relu(x) = 0

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 2</h1>
# </div>

# %%
# Usar un bucle for que calcule la norma euclidiana de un vector, representada como una lista.
# https://en.wikipedia.org/wiki/Norm_(mathematics

vector = [0.5, -1.2, 3.3, 4.5]
vector_2 = [0, 0, 0, 0, 0]
norma = 0

for i in range(len(vector)):
  vector_2[i] = vector[i] ** 2
  norma += vector_2

print("Norma euclidiana: ", norma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2871627058.py in <cell line: 0>()
#       8 for i in range(len(vector)):
#       9   vector_2[i] = vector[i] ** 2
# ---> 10   norma += vector_2
#      11
#      12 print("Norma euclidiana: ", norma)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 3</h1>
# </div>

# %%
# Usar 2 bucles for para encontrar el valor máximo de una matriz
# array_ordenado = np.array([[-4, -2, 1],[3, 5, 6]])

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 4</h1>
# </div>

# %%
# Use input para definir los parámetros necesarios para calcular el área de un rectángulo

alto = int(input("Ingrese el alto del rectángulo (sin unidades): "))
ancho  = int(input("Ingrese el ancho del rectángulo (sin unidades): "))
print("El área del cuadrado es", (alto * ancho), " unidades")
# Out:
# Ingrese el alto del rectángulo (sin unidades): 12
# Ingrese el ancho del rectángulo (sin unidades): 7
# El área del cuadrado es 84  unidades

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 5</h1>
# </div>

# %%
# Use input para ingresar un valor en grados Celsius, convierta e imprima el equivalente de la temperatura en grados Fahrenheit y Kelvin
# https://www.how-to-study.com/escalas-de-temperatura/

celsius = float(input("Ingrese la tempreratura (en Celcius): "))
fahrenheit = celsius * 1.8 + 32.
kelvin = celsius + 273.15
print(celsius, "º = ", fahrenheit, "ºF = ", kelvin, "ºK")
# Out:
# Ingrese la tempreratura (en Celcius): 0
# 0.0 º =  32.0 ºF =  273.15 ºK

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 6</h1>
# </div>

# %%
# Use input para ingrese su edad, calcular el año de nacimiento y estimar en que año Ud. tendrá 80 años

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 7</h1>
# </div>

# %%
# Calcular la suma de los primeros n números pares. El valor de n se proporciona como entrada por teclado usando input.

n = int(input("Ingrese el número que desee calcular: "))
ancho  = int(input("Ingrese el ancho del rectángulo (sin unidades): "))
resultado = print("El área del cuadrado es", (alto * ancho), " unidades")

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ejercicio 8</h1>
# </div>

# %%
# Use input para ingresar la tasa_interes, el tiempo y el monto inicial.
# Calcular el monto final (MF) después de ciertos años utilizando la fórmula del interés simple:
# MF=monto_inicial(1+tasa_interes×tiempo)

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1JTvS_vjZTzQfHiMOt9ZbfqmjNN1FvOOm'>
